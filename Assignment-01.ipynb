# %% [markdown]
# # ASSIGNMENT-1

# %% [markdown]
# TASK-1

# %%
#QUES1: Install Jupyter notebook and run the first program and share the screenshot of the output.

# %% [markdown]
# ![Screenshot%20%2818%29.png](attachment:Screenshot%20%2818%29.png)

# %%
#QUES2: Write a program which will find all such numbers which are divisible by 7 but are not a multiple
#of 5, between 2000 and 3200 (both included). The numbers obtained should be printed in a
#comma-separated sequence on a single line.

x=2000
while x>=2000 and x<=3200:
    if (x%7==0) and (x%5!=0):
        print(x,end=',')
    x=x+1

# %% [markdown]
# ![Screenshot%20%2819%29.png](attachment:Screenshot%20%2819%29.png)

# %%
#QUES3: Write a Python program to accept the user's first and last name and then getting them printed in
# the the reverse order with a space between first name and last name.

#please provide name(input) with sapce in between
first_name,last_name=[i for i in input("Enter the first name and last name: ").split(' ')]
full_name=first_name+' '+last_name
print(full_name[: :-1])

# %% [markdown]
# ![Screenshot%20%2820%29.png](attachment:Screenshot%20%2820%29.png)

# %%
#QUES4: Write a Python program to find the volume of a sphere with diameter 12 cm.
#Formula: V=4/3 * π * r^3 
import math
d=12
r=d/2
V=4/3*(math.pi)*(r**3)
print("Volume of sphere with diameter %dcm is %f cubic centimetre"%(d,V))

# %% [markdown]
# ![Screenshot%20%2821%29.png](attachment:Screenshot%20%2821%29.png)

# %% [markdown]
# TASK-2

# %%
#QUES1: Write a program which accepts a sequence of comma-separated numbers from console and
#generate a list.

num_list=list([int(x) for x in input("Enter the numbers with comma: ").split(',')])
print("Input Numbers:",num_list)

# %% [markdown]
# ![Screenshot%20%2822%29.png](attachment:Screenshot%20%2822%29.png)

# %%
#QUES2: Create the below pattern using nested for loop in Python. 
"""
*  
* *
* * *
* * * *
* * * * *
* * * *
* * *
* *
* 
"""


n=4
for i in range(n,-(n+1),-1):
    for j in range(n,abs(i)-1,-1):
        print("*",end='')
    print()

# %% [markdown]
# ![Screenshot%20%2823%29.png](attachment:Screenshot%20%2823%29.png)

# %%
#QUES3: Write a Python program to reverse a word after accepting the input from the user.
txt=input("Enter the text: ")
print(txt[: :-1])

# %% [markdown]
# ![Screenshot%20%2824%29.png](attachment:Screenshot%20%2824%29.png)

# %%
#QUES4: Write a Python Program to print the given string in the format specified in the sample output. 
 #WE, THE PEOPLE OF INDIA, having solemnly resolved to constitute India into a SOVEREIGN, SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC and to secure to all its citizens 

print("WE, THE PEOPLE OF INDIA,\n\thaving solemnly resolved to constitute India into a SOVEREIGN,!\n\t\t SOCIALIST, SECULAR, DEMOCRATIC REPUBLIC\n\t\t and to secure to all its citizens ")

# %% [markdown]
# ![Screenshot%20%2825%29.png](attachment:Screenshot%20%2825%29.png)
